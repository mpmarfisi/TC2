# %% [markdown]
# <img src="logo_UTN.svg" align="right" width="150" />
#
# ## Teoría de Circuitos II
#
# ### Tarea Semanal 2
#
# #### Por Matías Marfisi

# %% [markdown]
# #### Desarrollo transferencia, calculo componentes para w0 = 1 y Q = 3

# %% [markdown]
# ![Parte 1 desarrollo](Circuito_Papel.jpg "Parte 1 desarrollo")

# %% [markdown]
# ![Parte 2 desarrollo](Transferencia_Componentes.jpg "Parte 2 desarrollo")

# %% [markdown]
# ![Componentes](Componentes_2.jpg "Componentes")

# %% [markdown]
# #### Sensibilidad y Butterworth

# %% [markdown]
# ![Sensibilidad y Butter](Sensibilidad_Butter.jpg "Sensibilidad y Butter")

# %% [markdown]
# #### Normalizacion

# %% [markdown]
# ![Normalizacion 1](Normalizacion_1.jpg "Normalizacion 1")

# %% [markdown]
# ![Normalizacion 2](Normalizacion_2.jpg "Normalizacion 2")

# %% [markdown]
# #### Filtro pasabanda tomando salida en V1

# %% [markdown]
# ![Pasabanda](Desarrollo_Pasabanda.jpg "Pasabanda")

# %% [markdown]
# #### Simulación w0 = 1 y Q = 3

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (10,10)


#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

#fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
#plt.rcParams.update({'font.family':fig_font_family})

# módulo de SciPy
from scipy import signal as sig

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq

# %%
from splane import analyze_sys, pretty_print_bicuad_omegayq
# Comienzo Ejercicio
R1 = 100e3 
R2 = 3e6
R3 = 1e6
R4 = 1e6
C = 1e-6

K = -R3/R1
num = np.array([K * 1/(C**2 * R3**2)])
den = np.array([1, 1/(C*R2),1/(C**2 * R3**2)])

sistema = sig.TransferFunction(num,den)

pretty_print_bicuad_omegayq(num,den)

mi_sos = sig.TransferFunction(num,den)

plt.close('all')
analyze_sys(sistema, 'Pasabajos')
# Out:
# $\displaystyle \frac{-10 }{s^2 + s \frac{  1}{  3} +   1^2}$

# %%
from splane import analyze_sys, pretty_print_bicuad_omegayq
# Comienzo Ejercicio
R1 = 100e3 
R2 = 3e6
R3 = 1e6
R4 = 1e6
C = 1e-6

K = -R2/R1
num = np.array([1/(C*R2), 0])
den = np.array([1, 1/(C*R2),1/(C**2 * R3**2)])

sistema = sig.TransferFunction(num,den)

pretty_print_bicuad_omegayq(num,den)

mi_sos = sig.TransferFunction(num,den)

plt.close('all')
analyze_sys(sistema, 'Pasabanda')
# Out:
# $\displaystyle \frac{s\,  1\,\frac{  1}{  3}}{s^2 + s \frac{  1}{  3} +   1^2}$

# %% [markdown]
# #### Simulación en Spice

# %% [markdown]
# ![Circuito Spice](Circuito.png "Circuito Spice")

# %% [markdown]
# ##### Simulación de módulo, fase y retardo de grupo pasabajos

# %% [markdown]
# ![Simulacion Pasabajos](Simulacion_Pasabajos.png "Simulacion Pasabajos")

# %% [markdown]
# ##### Simulación de módulo, fase y retardo de grupo pasabanda tomando salida primer OPAMP

# %% [markdown]
# ![Simulacion_Pasabanda](Simulacion_Pasabanda.png "Simulacion_Pasabanda")
