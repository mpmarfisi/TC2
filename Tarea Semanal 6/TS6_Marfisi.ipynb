# %% [markdown]
# <img src="logo_UTN.svg" align="right" width="150" />
#
# ## Teoría de Circuitos II
#
# ### Tarea Semanal 6
#
# #### Por Matías Marfisi

# %% [markdown]
# ![Consigna](EJ1.png "Consigna")

# %% [markdown]
# ## Desarrollo

# %% [markdown]
# ### Punto A

# %% [markdown]
# ![1](Desarrollo/1_1.jpg "1")

# %% [markdown]
# ![1](Desarrollo/1_2.jpg "1")

# %% [markdown]
# ### Punto B

# %% [markdown]
# ![1](Desarrollo/1_3.jpg "1")

# %% [markdown]
# ![1](Desarrollo/1_4.jpg "1")

# %% [markdown]
# ## Simulación

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (25,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

#fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
#plt.rcParams.update({'font.family':fig_font_family})

# módulo de SciPy
from scipy import signal as sig

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq

# %%
from splane import analyze_sys, pretty_print_bicuad_omegayq
# 1A
num1 = np.array([1, -1])
den1 = np.array([1, 1])

sos_1 = sig.TransferFunction(num1,den1)

all_sos = [sos_1]

plt.close('all')
analyze_sys(all_sos, sys_name=['SOS1'])

# %% [markdown]
# ## SPICE

# %% [markdown]
# ### Circuito Pasivo

# %% [markdown]
# ![Circuito Pasivo](Simulaciones/Circuito_Pasatodo_Pasivo.png "Circuito Pasivo")

# %% [markdown]
# ![Circuito Pasivo](Simulaciones/Fase_Pasatodo_Pasivo.png "Circuito Pasivo")

# %% [markdown]
# Se observa que se tienen los 165° en la frecuencia deseada, 0.159Hz * 2pi = 1.

# %% [markdown]
# ### Circuito Activo

# %% [markdown]
# ![Circuito Activo](Simulaciones/Circuito_Pasatodo_Activo.png "Circuito Activo")

# %% [markdown]
# ![Circuito Activo](Simulaciones/Fase_Pasatodo_Activo.png "Circuito Activo")

# %% [markdown]
# Se observa que se tienen los 165° en la frecuencia deseada, 0.159Hz * 2pi = 1.

# %% [markdown]
# # Consigna

# %% [markdown]
# ![Consigna](Consigna1.png "Consigna")

# %% [markdown]
# ![Consigna](Consigna2.png "Consigna")

# %% [markdown]
# ![Consigna](Consigna3.png "Consigna")

# %% [markdown]
# ## Simulación

# %%
# Módulos para Jupyter

import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
#%%  Inicialización de librerías
# Setup inline graphics: Esto lo hacemos para que el tamaño de la salida, 
# sea un poco más adecuada al tamaño del documento
mpl.rcParams['figure.figsize'] = (25,10)

#%% Esto tiene que ver con cuestiones de presentación de los gráficos,
# NO ES IMPORTANTE
fig_sz_x = 14
fig_sz_y = 13
fig_dpi = 80 # dpi

#fig_font_family = 'Ubuntu'
fig_font_size = 16

plt.rcParams.update({'font.size':fig_font_size})
#plt.rcParams.update({'font.family':fig_font_family})

# módulo de SciPy
from scipy import signal as sig

# un módulo adaptado a mis necesidades
from splane import analyze_sys, pretty_print_bicuad_omegayq

# %% [markdown]
# ### Estructura pasa-bajo

# %%
from splane import analyze_sys, pretty_print_bicuad_omegayq

K = 1/9;
num1 = K * np.array([1, 0, 3**2])
den1 = np.array([1, np.sqrt(2), 1])
den2 = np.array([1, 1])

den1_aux = np.polymul(den1,den2)

sos_1 = sig.TransferFunction(num1,den1_aux)

all_sos = [sos_1]

pretty_print_bicuad_omegayq(num1,den1)

plt.close('all')
analyze_sys(all_sos, sys_name=['SOS1'])
# Out:
# $\displaystyle \frac{s^2 \,\, 0.1111 +   1 }{s^2 + s \frac{  1}{0.7071} +   1^2}$

# %% [markdown]
# ### Estructura pasa-altos

# %%
from splane import analyze_sys, pretty_print_bicuad_omegayq
K = 1;
num1 = K * np.array([1, 0, 1**2])
den1 = np.array([1, np.sqrt(2)*3, 3**2])
num2 = np.array([1, 0]);
den2 = np.array([1, 1])

num1_aux = np.polymul(num1,num2)
den1_aux = np.polymul(den1,den2)

sos_1 = sig.TransferFunction(num1_aux,den1_aux)

all_sos = [sos_1]

pretty_print_bicuad_omegayq(num1,den1)

plt.close('all')
analyze_sys(all_sos, sys_name=['SOS1'])
# Out:
# $\displaystyle \frac{s^2 +   1 }{s^2 + s \frac{  3}{0.7071} +   3^2}$
